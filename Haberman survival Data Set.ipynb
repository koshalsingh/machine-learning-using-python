# %% [markdown]
# # EDA for Haberman's Survival Data Set
# Survival of patients who had undergone surgery for breast cancer

# %% [markdown]
# About Data Set:-
#
# 1.The dataset contains cases from a study that was conducted between 1958 and 1970 at the University of Chicago's Billings Hospital on the survival of patients who had undergone surgery for breast cancer.
#
# 2.Relevant Information: The dataset contains cases from a study that was conducted between 1958 and 1970 at the University of Chicago's Billings Hospital on the survival of patients who had undergone surgery for breast cancer.
#
# 3.Number of Instances: 306
#
# 4.Number of Attributes: 4 (including the class attribute)
#
# 5.Attribute Information:
#     Age of patient at time of operation (numerical)
#     Patient's year of operation (year - 1900, numerical)
#     Number of positive axillary nodes detected (numerical)
#     Survival status (class attribute) 1 = the patient survived 5 years or longer 2 = the patient died within 5 year
#
# 6.Missing Attribute Values: None
#
# 7.Download Haberman Cancer Survival dataset from Kaggle. You may have to create a Kaggle account to donwload data. (https://www.kaggle.com/gilsousa/habermans-survival-data-set)

# %% [markdown]
# Objective:- To find the the most survival patient's age.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

#load hiberman1.csv in pandas dataframe
hbm = pd.read_csv("haberman1.csv")

# %%
#how many data points and features?
print(hbm.shape)
# Out:
# (306, 4)

# %%
#What are the column names in our dataset?
print(hbm.columns)
# Out:
# Index(['Age', 'year of operation (1900)',
#        'Number of positive axillary nodes detected', 'Survival status'],
#       dtype='object')

# %%
#(Q) How many data points for each class are present? 
#(or) how many survived.
print(hbm['Survival status'].value_counts())
# Out:
# 1    225
# 2     81
# Name: Survival status, dtype: int64

# %%
#(Q) How many data points for each class are present(on this basis of age)?
print(hbm['Age'].value_counts())
# Out:
# 52    14
# 54    13
# 50    12
# 47    11
# 53    11
# 43    11
# 57    11
# 55    10
# 65    10
# 49    10
# 38    10
# 41    10
# 61     9
# 45     9
# 42     9
# 63     8
# 59     8
# 62     7
# 44     7
# 58     7
# 56     7
# 46     7
# 70     7
# 34     7
# 48     7
# 37     6
# 67     6
# 60     6
# 51     6
# 39     6
# 66     5
# 64     5
# 72     4
# 69     4
# 40     3
# 30     3
# 68     2
# 73     2
# 74     2
# 36     2
# 35     2
# 33     2
# 31     2
# 78     1
# 71     1
# 75     1
# 76     1
# 77     1
# 83     1
# Name: Age, dtype: int64

# %% [markdown]
# #2-D Scatter Plot

# %%
#plotting 2D scatter for age and survival status 
hbm.plot(kind='scatter', x ='Age', y='Survival status')
plt.show()

# %%
#2-D Scatter plot with color-coding for age and survival status

sb.set_style()
sb.FacetGrid(hbm, hue='Survival status', size=4)\
.map(plt.scatter,"Age","Survival status")\
.add_legend()
plt.show()

# %% [markdown]
# **Observation**:
# we can find the most survivals using Age and Survival Status.

# %% [markdown]
# # 3D Scatter plot

# %% [markdown]
# # pair plot

# %%
# pairwise scatter plot: Pair-Plot
# Dis-advantages: 
##Can be used when number of features are high.
##Cannot visualize higher dimensional patterns in 3-D and 4-D. 
#Only possible to view 2D patterns.

plt.close()
sb.set_style('whitegrid')
sb.pairplot(hbm, hue='Survival status', size=4)
plt.show()

# %% [markdown]
# **Observations**

# %% [markdown]
# # Histogram

# %%
# 1-D scatter plot using just one feature
#1-D scatter plot of Age
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

#load hiberman1.csv in pandas dataframe
hbm = pd.read_csv("haberman1.csv")
survived = hbm.loc[hbm['Survival status']==1]
died = hbm.loc[hbm['Survival status']==2]

print(survived['Age'])
print(died['Age'])
# Out:
# 0      30
# 1      30
# 2      30
# 3      31
# 4      31
# 5      33
# 6      33
# 9      34
# 10     34
# 11     34
# 12     34
# 13     34
# 14     35
# 15     35
# 16     36
# 17     36
# 18     37
# 19     37
# 20     37
# 21     37
# 22     37
# 23     37
# 25     38
# 26     38
# 27     38
# 28     38
# 29     38
# 30     38
# 31     38
# 32     38
#        ..
# 265    65
# 266    65
# 267    65
# 270    66
# 271    66
# 272    66
# 275    67
# 276    67
# 277    67
# 278    67
# 279    68
# 280    68
# 282    69
# 283    69
# 284    69
# 287    70
# 288    70
# 289    70
# 290    70
# 291    70
# 292    71
# 294    72
# 295    72
# 296    72
# 297    73
# 298    73
# 300    74
# 301    75
# 302    76
# 303    77
# Name: Age, Length: 225, dtype: int64
# 7      34
# 8      34
# 24     38
# 34     39
# 43     41
# 44     41
# 45     41
# 53     42
# 54     42
# 62     43
# 63     43
# 64     43
# 65     43
# 73     44
# 74     44
# 75     44
# 80     45
# 81     45
# 82     45
# ...
